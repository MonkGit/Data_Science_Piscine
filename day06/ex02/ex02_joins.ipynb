# %%
import pandas as pd
import sqlite3

# %% [markdown]
# create a connection to the database using the library sqlite3

# %%
con = sqlite3.connect("../data/checking-logs.sqlite.sqlite_copy")

# %%
# просто напомнить себе как выглядит таблица
query = '''
SELECT * FROM checker LIMIT 10'''

pd.io.sql.read_sql(query, con)
# Out:
#    index    status  success                   timestamp  numTrials   labname  \
# 0      0  checking        0  2020-04-16 21:12:50.740474          5      None
# 1      1     ready        0  2020-04-16 21:12:54.708365          5  code_rvw
# 2      2  checking        0  2020-04-16 21:46:47.769088          7      None
# 3      3     ready        0  2020-04-16 21:46:48.121217          7     lab02
# 4      4  checking        0  2020-04-16 21:53:01.862637          6  code_rvw
# 5      5     ready        0  2020-04-16 21:53:05.373389          6  code_rvw
# 6      6  checking        0  2020-04-17 05:18:51.965864          1      None
# 7      7     ready        0  2020-04-17 05:19:02.744528          1  project1
# 8      8  checking        0  2020-04-17 05:22:35.249331          2  project1
# 9      9     ready        1  2020-04-17 05:22:45.549397          2  project1
#
#        uid
# 0  admin_1
# 1  admin_1
# 2  admin_1
# 3  admin_1
# 4  admin_1
# 5  admin_1
# 6     None
# 7   user_4
# 8   user_4
# 9   user_4

# %%
query = '''
SELECT * FROM pageviews LIMIT 10'''

pd.io.sql.read_sql(query, con)
# Out:
#    index      uid                    datetime
# 0      0  admin_1  2020-04-17 12:01:08.463179
# 1      1  admin_1  2020-04-17 12:01:23.743946
# 2      2  admin_3  2020-04-17 12:17:39.287778
# 3      3  admin_3  2020-04-17 12:17:40.001768
# 4      4  admin_1  2020-04-17 12:27:30.646665
# 5      5  admin_1  2020-04-17 12:35:44.884757
# 6      6  admin_1  2020-04-17 12:35:52.735016
# 7      7  admin_3  2020-04-17 12:36:21.401412
# 8      8  admin_3  2020-04-17 12:36:22.023355
# 9      9  admin_1  2020-04-17 13:55:19.129243

# %% [markdown]
# create a new table datamart in the database
#
# by joining the tables pageviews and checker using only one query
#
#     ◦ the table should have the following columns: uid, labname, first_commit_ts, first_view_ts
#
#     ◦ first_commit_ts is just a new name of the column timestamp from the checker table, it shows the first commit from a particular lab and from a particular user
#
#     ◦ first_view_ts is the first visit of a user to the table pageviews, timestamp when a user visited the newsfeed
#
#     ◦ status = ’ready’ should still be a filter
#
#     ◦ numTrials = 1 should still be a filter
#
#     ◦ labnames should still be from the list: ’laba04’, ’laba04s’, ’laba05’, ’laba06’, ’laba06s’, ’project1’
#
#
#     ◦ the table should contain only the users (uids with user_*) and not the admins

# %%
query = '''
SELECT checker.uid,
       checker.labname,
       checker.timestamp AS first_commit_ts,
       pageviews.datetime AS first_view_ts
FROM checker 
LEFT JOIN pageviews ON checker.uid=pageviews.uid
WHERE status='ready'
AND numTrials=1
AND labname IN ('laba04', 'laba04s', 'laba05', 'laba06', 'laba06s', 'project1')
AND checker.uid LIKE 'user_%'
AND (pageviews.datetime = (SELECT MIN(pageviews.datetime)
                           FROM pageviews
                           WHERE uid=checker.uid)
        OR pageviews.datetime IS NULL)
'''
datamart = pd.io.sql.read_sql(query, con, parse_dates=[
                              'first_commit_ts', 'first_view_ts'])
datamart
# Out:
#          uid   labname            first_commit_ts              first_view_ts
# 0     user_4  project1 2020-04-17 05:19:02.744528                        NaT
# 1     user_4    laba04 2020-04-17 11:33:17.366400                        NaT
# 2     user_4   laba04s 2020-04-17 11:48:41.992466                        NaT
# 3    user_17  project1 2020-04-18 07:56:45.408648 2020-04-18 10:56:55.833899
# 4    user_30    laba04 2020-04-18 13:36:53.971502 2020-04-17 22:46:26.785035
# ..       ...       ...                        ...                        ...
# 135  user_23    laba06 2020-05-21 08:34:10.517205                        NaT
# 136  user_19   laba06s 2020-05-21 13:27:06.705881 2020-04-21 20:30:38.034966
# 137  user_23   laba06s 2020-05-21 14:29:15.709568                        NaT
# 138  user_17    laba06 2020-05-21 15:21:31.567615 2020-04-18 10:56:55.833899
# 139  user_17   laba06s 2020-05-21 17:39:17.783615 2020-04-18 10:56:55.833899
#
# [140 rows x 4 columns]

# %% [markdown]
# ## using Pandas methods, create two dataframes: test and control
#
#     ◦ test should have the users that have the values in first_view_ts
#     ◦ control should have the users that have missing values in first_view_ts

# %%
test = datamart[~datamart['first_view_ts'].isnull()]
test.head()
# Out:
#         uid   labname            first_commit_ts              first_view_ts
# 3   user_17  project1 2020-04-18 07:56:45.408648 2020-04-18 10:56:55.833899
# 4   user_30    laba04 2020-04-18 13:36:53.971502 2020-04-17 22:46:26.785035
# 7   user_30   laba04s 2020-04-18 14:51:37.498399 2020-04-17 22:46:26.785035
# 8   user_14    laba04 2020-04-18 15:14:00.312338 2020-04-18 10:53:52.623447
# 11  user_14   laba04s 2020-04-18 22:30:30.247628 2020-04-18 10:53:52.623447

# %% [markdown]
#     ◦ replace the missing values in the control with the average first_view_ts of the test users, we will use this value for the future analysis

# %%
control = datamart[datamart['first_view_ts'].isnull()]
control = control.fillna(test['first_view_ts'].mean())
control
# Out:
#          uid   labname            first_commit_ts  \
# 0     user_4  project1 2020-04-17 05:19:02.744528
# 1     user_4    laba04 2020-04-17 11:33:17.366400
# 2     user_4   laba04s 2020-04-17 11:48:41.992466
# 5     user_2    laba04 2020-04-18 13:42:35.482008
# 6     user_2   laba04s 2020-04-18 13:51:22.291271
# ..       ...       ...                        ...
# 126   user_2   laba06s 2020-05-19 14:45:03.908268
# 132   user_6   laba06s 2020-05-20 14:50:07.609937
# 134   user_7   laba06s 2020-05-20 23:05:37.742597
# 135  user_23    laba06 2020-05-21 08:34:10.517205
# 137  user_23   laba06s 2020-05-21 14:29:15.709568
#
#                     first_view_ts
# 0   2020-04-27 00:40:05.761783552
# 1   2020-04-27 00:40:05.761783552
# 2   2020-04-27 00:40:05.761783552
# 5   2020-04-27 00:40:05.761783552
# 6   2020-04-27 00:40:05.761783552
# ..                            ...
# 126 2020-04-27 00:40:05.761783552
# 132 2020-04-27 00:40:05.761783552
# 134 2020-04-27 00:40:05.761783552
# 135 2020-04-27 00:40:05.761783552
# 137 2020-04-27 00:40:05.761783552
#
# [81 rows x 4 columns]

# %% [markdown]
#     ◦ save both tables into the database, you will use them in the next exercises

# %%
test.to_sql('test', con)
control.to_sql('control', con)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [24], line 1
# ----> 1 test.to_sql('test', con)
#       2 control.to_sql('control', con)
#
# File ~/Documents/Data_Science_Piscine/day05/slaree/lib/python3.9/site-packages/pandas/core/generic.py:2986, in NDFrame.to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    <a href='file:///Users/slaree/Documents/Data_Science_Piscine/day05/slaree/lib/python3.9/site-packages/pandas/core/generic.py?line=2828'>2829</a> """
#    <a href='file:///Users/slaree/Documents/Data_Science_Piscine/day05/slaree/lib/python3.9/site-packages/pandas/core/generic.py?line=2829'>2830</a> Write records stored in a DataFrame to a SQL database.
#    <a href='file:///Users/slaree/Documents/Data_Science_Piscine/day05/slaree/lib/python3.9/site-packages/pandas/core/generic.py?line=2830'>2831</a>
#    (...)
#    <a href='file:///Users/slaree/Documents/Data_Science_Piscine/day05/slaree/lib/python3.9/site-packages/pandas/core/generic.py?line=2981'>2982</a> [(1,), (None,), (2,)]
#    <a href='file:///Users/slaree/Documents/Data_Science_Piscine/day05/slaree/lib/python3.9/site-packages/pandas/core/generic.py?line=2982'>2983</a> """  # noqa:E501
#    <a href='file:///Users/slaree/Documents/Data_Science_Piscine/day05/slaree/lib/python3.9/site-packages/pandas/core/generic.py?line=2983'>2984</a> from pandas.io import sql
# -> <a href='file:///Users/slaree/Documents/Data_Science_Piscine/day05/slaree/lib/python3.9/site-packages/pandas/core/generic.py?line=2985'>2986</a> return sql.to_sql(
#    <a href='file:///Users/slaree/Documents/Data_Science_Piscine/day05/slaree/lib/python3.9/site-packages/pandas/core/generic.py?line=2986'>2987</a>     self,
#    <a href='file:///Users/slaree/Documents/Data_Science_Piscine/day05/slaree/lib/python3.9/site-packages/pandas/core/generic.py?line=2987'>2988</a>     name,
#    <a href='file:///Users/slaree/Documents/Data_Science_Piscine/day05/slaree/lib/python3.9/site-packages/pandas/core/generic.py?line=2988'>2989</a>     con,
#    <a href='file:///Users/slaree/Documents/Data_Science_Piscine/day05/slaree/lib/python3.9/site-packages/pandas/core/generic.py?line=2989'>2990</a>     schema=schema,
#    <a href='file:///Users/slaree/Documents/Data_Science_Piscine/day05/slaree/lib/python3.9/site-packages/pandas/core/generic.py?line=2990'>2991</a>     if_exists=if_exists,
#    <a href='file:///Users/slaree/Documents/Data_Science_Piscine/day05/slaree/lib/python3.9/site-packages/pandas/core/generic.py?line=2991'>2992</a>     index=index,
#    <a href='file:///Users/slaree/Documents/Data_Science_Piscine/day05/slaree/lib/python3.9/site-packages/pandas/core/generic.py?line=2992'>2993</a>     index_label=index_label,
#    <a href='file:///Users/slaree/Documents/Data_Science_Piscine/day05/slaree/lib/python3.9/site-packages/pandas/core/generic.py?line=2993'>2994</a>     chunksize=chunksize,
#    <a href='file:///Users/slaree/Documents/Data_Science_Piscine/day05/slaree/lib/python3.9/site-packages/pandas/core/generic.py?line=2994'>2995</a>     dtype=dtype,
#    <a href='file:///Users/slaree/Documents/Data_Science_Piscine/day05/slaree/lib/python3.9/site-packages/pandas/core/generic.py?line=2995'>2996</a>     method=method,
#    <a href='file:///Users/slaree/Documents/Data_Science_Piscine/day05/slaree/lib/python3.9/site-packages/pandas/core/generic.py?line=2996'>2997</a> )
#
# File ~/Documents/Data_Science_Piscine/day05/slaree/lib/python3.9/site-packages/pandas/io/sql.py:696, in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     <a href='file:///Users/slaree/Documents/Data_Science_Piscine/day05/slaree/lib/python3.9/site-packages/pandas/io/sql.py?line=690'>691</a> elif not isinstance(frame, DataFrame):
#     <a href='file:///Users/slaree/Documents/Data_Science_Piscine/day05/slaree/lib/python3.9/site-packages/pandas/io/sql.py?line=691'>692</a>     raise NotImplementedError(
#     <a href='file:///Users/slaree/Documents/Data_Science_Piscine/day05/slaree/lib/python3.9/site-packages/pandas/io/sql.py?line=692'>693</a>         "'frame' argument should be either a Series or a DataFrame"
#     <a href='file:///Users/slaree/Documents/Data_Science_Piscine/day05/slaree/lib/python3.9/site-packages/pandas/io/sql.py?line=693'>694</a>     )
# --> <a href='file:///Users/slaree/Documents/Data_Science_Piscine/day05/slaree/lib/python3.9/site-packages/pandas/io/sql.py?line=695'>696</a> return pandas_sql.to_sql(
#     <a href='file:///Users/slaree/Documents/Data_Science_Piscine/day05/slaree/lib/python3.9/site-packages/pandas/io/sql.py?line=696'>697</a>     frame,
#     <a href='file:///Users/slaree/Documents/Data_Science_Piscine/day05/slaree/lib/python3.9/site-packages/pandas/io/sql.py?line=697'>698</a>     name,
#     <a href='file:///Users/slaree/Documents/Data_Science_Piscine/day05/slaree/lib/python3.9/site-packages/pandas/io/sql.py?line=698'>699</a>     if_exists=if_exists,
#     <a href='file:///Users/slaree/Documents/Data_Science_Piscine/day05/slaree/lib/python3.9/site-packages/pandas/io/sql.py?line=699'>700</a>     index=index,
#     <a href='file:///Users/slaree/Documents/Data_Science_Piscine/day05/slaree/lib/python3.9/site-packages/pandas/io/sql.py?line=700'>701</a>     index_label=index_label,
#     <a href='file:///Users/slaree/Documents/Data_Science_Piscine/day05/slaree/lib/python3.9/site-packages/pandas/io/sql.py?line=701'>702</a>     schema=schema,
#     <a href='file:///Users/slaree/Documents/Data_Science_Piscine/day05/slaree/lib/python3.9/site-packages/pandas/io/sql.py?line=702'>703</a>     chunksize=chunksize,
#     <a href='file:///Users/slaree/Documents/Data_Science_Piscine/day05/slaree/lib/python3.9/site-packages/pandas/io/sql.py?line=703'>704</a>     dtype=dtype,
#     <a href='file:///Users/slaree/Documents/Data_Science_Piscine/day05/slaree/lib/python3.9/site-packages/pandas/io/sql.py?line=704'>705</a>     method=method,
#     <a href='file:///Users/slaree/Documents/Data_Science_Piscine/day05/slaree/lib/python3.9/site-packages/pandas/io/sql.py?line=705'>706</a>     engine=engine,
#     <a href='file:///Users/slaree/Documents/Data_Science_Piscine/day05/slaree/lib/python3.9/site-packages/pandas/io/sql.py?line=706'>707</a>     **engine_kwargs,
#     <a href='file:///Users/slaree/Documents/Data_Science_Piscine/day05/slaree/lib/python3.9/site-packages/pandas/io/sql.py?line=707'>708</a> )
#
# File ~/Documents/Data_Science_Piscine/day05/slaree/lib/python3.9/site-packages/pandas/io/sql.py:2188, in SQLiteDatabase.to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method, **kwargs)
#    <a href='file:///Users/slaree/Documents/Data_Science_Piscine/day05/slaree/lib/python3.9/site-packages/pandas/io/sql.py?line=2176'>2177</a>             raise ValueError(f"{col} ({my_type}) not a string")
#    <a href='file:///Users/slaree/Documents/Data_Science_Piscine/day05/slaree/lib/python3.9/site-packages/pandas/io/sql.py?line=2178'>2179</a> table = SQLiteTable(
#    <a href='file:///Users/slaree/Documents/Data_Science_Piscine/day05/slaree/lib/python3.9/site-packages/pandas/io/sql.py?line=2179'>2180</a>     name,
#    <a href='file:///Users/slaree/Documents/Data_Science_Piscine/day05/slaree/lib/python3.9/site-packages/pandas/io/sql.py?line=2180'>2181</a>     self,
#    (...)
#    <a href='file:///Users/slaree/Documents/Data_Science_Piscine/day05/slaree/lib/python3.9/site-packages/pandas/io/sql.py?line=2185'>2186</a>     dtype=dtype,
#    <a href='file:///Users/slaree/Documents/Data_Science_Piscine/day05/slaree/lib/python3.9/site-packages/pandas/io/sql.py?line=2186'>2187</a> )
# -> <a href='file:///Users/slaree/Documents/Data_Science_Piscine/day05/slaree/lib/python3.9/site-packages/pandas/io/sql.py?line=2187'>2188</a> table.create()
#    <a href='file:///Users/slaree/Documents/Data_Science_Piscine/day05/slaree/lib/python3.9/site-packages/pandas/io/sql.py?line=2188'>2189</a> return table.insert(chunksize, method)
#
# File ~/Documents/Data_Science_Piscine/day05/slaree/lib/python3.9/site-packages/pandas/io/sql.py:830, in SQLTable.create(self)
#     <a href='file:///Users/slaree/Documents/Data_Science_Piscine/day05/slaree/lib/python3.9/site-packages/pandas/io/sql.py?line=827'>828</a> if self.exists():
#     <a href='file:///Users/slaree/Documents/Data_Science_Piscine/day05/slaree/lib/python3.9/site-packages/pandas/io/sql.py?line=828'>829</a>     if self.if_exists == "fail":
# --> <a href='file:///Users/slaree/Documents/Data_Science_Piscine/day05/slaree/lib/python3.9/site-packages/pandas/io/sql.py?line=829'>830</a>         raise ValueError(f"Table '{self.name}' already exists.")
#     <a href='file:///Users/slaree/Documents/Data_Science_Piscine/day05/slaree/lib/python3.9/site-packages/pandas/io/sql.py?line=830'>831</a>     elif self.if_exists == "replace":
#     <a href='file:///Users/slaree/Documents/Data_Science_Piscine/day05/slaree/lib/python3.9/site-packages/pandas/io/sql.py?line=831'>832</a>         self.pd_sql.drop_table(self.name, self.schema)
#
# ValueError: Table 'test' already exists.

# %% [markdown]
#     close the connection

# %%
con.close()
